# %% [markdown]
# <a href="https://colab.research.google.com/github/psyuktha/DeviVerse/blob/main/Preparing_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def read_text_file(file_path):
    try:
        with open(file_path, 'r') as file:
            content = file.read()
            return content
    except FileNotFoundError:
        return f"File not found: {file_path}"

file_content = read_text_file('/content/soundarya_lahari.txt')
file_content
# Out:
# '1\nशिवः शक्त्या युक्तो यदि भवति शक्तः प्रभवितुं\nन चेदेवं देवो न खलु कुशलः स्पन्दितुमपि।\nअतस्त्वामारध्यां हरिहरविरिञ्चादिभिरपि\nप्रणन्तुं स्तोतुं वा कथमकृतपुण्यः प्रभवति॥\nŚivaḥ śaktyā yukto yadi bhavati śaktaḥ prabhavituṁ\nna cedevaṁ devo na khalu kuśalaḥ spanditumapi|\nAtastvāmārādhyāṁ hariharaviriñcādibhirapi\npraṇantuṁ stotuṁ vā kathamakṛtapuṇyaḥ prabhavati||\n Śivaḥ - tāntric Śiva i.e. God Himself; yadi - if; yuktaḥ - joined with; Śaktyā – Śakti; bhavati – becomes; śaktaḥ - capable of; prabhavituṁ - manifesting; (but)  ced – if; na - He is not; evam - thus (i.e. if He is not united with Śakti); devaḥ - Śiva;  na khalu  api - is certainly not even; kuśalaḥ  - able; spanditum - to vibrate; Atas - For this reason; katham – how; akṛtapuṇyaḥ  - is the one who has not accomplished meritorious acts;  prabhavati - able to; praṇantuṁ  - bow; vā – or; stotuṁ – praise; tvām  - You; ārādhyām  - who are to be worshiped; api – even; by hari -Viṣṇu;  hara - purānic Śiva; viriñca – Brahmā; ap
# ...

# %%
divided=file_content.split('--------------------------------------------------')

# %%
len(divided)
# Out:
# 90

# %%
def process_file_content(lines):
    # if isinstance(file_content, str) and "File not found" in file_content:
    #     print(file_content)  # Handle file not found error
    #     return pd.DataFrame(columns=['Instruction', 'Output']) # Return empty DataFrame
    instruction=[]
    output=[]
    division=[]
    for i in range(len(lines)):
      if lines[i]=='--------------------------------------------------':
        output.append(''.join(lines[:i]))
        instruction.append(''.join(lines[i+1:i+5]))


    df = pd.DataFrame({'Instruction': instruction, 'Output': output})
    return df

# %%
verse=[]
instruction=[]
output=[]

# %%
line=divided[0].split('\n')
verse.append(''.join(line[0]))
verse.append(''.join(line[0]))
instruction.append(''.join(line[1:5]))
instruction.append(''.join(line[5:9]))
output.append(''.join(line[9:]))
output.append(''.join(line[9:]))

# %%
for i in range(1,len(divided)):
  # print(divided[i])
  lines=divided[i].split("\n")
  verse.append(''.join(lines[1]))
  verse.append(''.join(lines[1]))
  instruction.append(''.join(lines[2:6]))
  instruction.append(''.join(lines[6:10]))
  output.append(''.join(lines[10:]))
  output.append(''.join(lines[10:]))

# %%
len(verse),len(instruction),len(output)
# Out:
# (180, 180, 180)

# %%
instruction[:10]
# Out:
# ['शिवः शक्त्या युक्तो यदि भवति शक्तः प्रभवितुंन चेदेवं देवो न खलु कुशलः स्पन्दितुमपि।अतस्त्वामारध्यां हरिहरविरिञ्चादिभिरपिप्रणन्तुं स्तोतुं वा कथमकृतपुण्यः प्रभवति॥',
#  'Śivaḥ śaktyā yukto yadi bhavati śaktaḥ prabhavituṁna cedevaṁ devo na khalu kuśalaḥ spanditumapi|Atastvāmārādhyāṁ hariharaviriñcādibhirapipraṇantuṁ stotuṁ vā kathamakṛtapuṇyaḥ prabhavati||',
#  'तनीयांसं पांसुं तव चरण पङ्केरुहभवंविरिञ्चिः संचिन्वन् विरचयति लोकानविकलम्।वहत्येनं शौरिः कथमपि सहस्रेण शिरसांहरः संक्षुद्यैनं भजति भसितोद्धूलनविधिम्॥',
#  'tanīyāṁsaṁ pāṁsuṁ tava caraṇa paṅkeruhabhavaṃviriñciḥ saṁcinvan viracayati lokānavikalam|vahatyeanaṁ śauriḥ kathamapi sahasreṇa śirasāṁharaḥ saṁkṣudyainaṁ bhajati bhasitoddhūlanavidhim||',
#  'अविद्यानामन्तस्तिमिरमिहिरद्वीपनगरी1जडानां चैतन्यस्तबकमकरन्दस्रुतिझरी।दरिद्राणां चिन्तामणिगुणनिका जन्मजलधौनिमग्नानां दंष्ट्रा सुररिपुवराहस्य भवती2॥',
# ...

# %%
import pandas as pd
df = pd.DataFrame({'Verse': verse, 'Instruction': instruction, 'Output': output})
df.head()
# Out:
#   Verse                                        Instruction  \
# 0     1  शिवः शक्त्या युक्तो यदि भवति शक्तः प्रभवितुंन ...
# 1     1  Śivaḥ śaktyā yukto yadi bhavati śaktaḥ prabhav...
# 2     2  तनीयांसं पांसुं तव चरण पङ्केरुहभवंविरिञ्चिः सं...
# 3     2  tanīyāṁsaṁ pāṁsuṁ tava caraṇa paṅkeruhabhavaṃv...
# 4     3  अविद्यानामन्तस्तिमिरमिहिरद्वीपनगरी1जडानां चैतन...
#
#                                               Output
# 0   Śivaḥ - tāntric Śiva i.e. God Himself; yadi -...
# 1   Śivaḥ - tāntric Śiva i.e. God Himself; yadi -...
# 2  This verse further explains the Supremacy of Ś...
# 3  This verse further explains the Supremacy of Ś...
# 4  Variations in texts:1. nakarī नकरी2. bhavati भ...

# %%
k=df.iloc[142]['Instruction'].index('3')
df.iloc[142]['Output']=df.iloc[142]['Instruction']
df.iloc[142]['Instruction']=df.iloc[142]['Instruction'][:k+1]
# Out:
# <ipython-input-150-e1e35e006375>:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df.iloc[142]['Output']=df.iloc[142]['Instruction']
# ...

# %%
df.iloc[142]
# Out:
# Verse                                                         72
# Instruction                    Twelve verses from verse 72 to 83
# Output         Twelve verses from verse 72 to 83 involve phys...
# Name: 142, dtype: object

# %%
df.iloc[143]=df.iloc[142]

# %%
df.iloc[143]
# Out:
# Verse                                                         72
# Instruction                    Twelve verses from verse 72 to 83
# Output         Twelve verses from verse 72 to 83 involve phys...
# Name: 143, dtype: object

# %%
df.iloc[144]["Instruction"]=df.iloc[144]["Instruction"][8:]
# Out:
# <ipython-input-154-1bc91a896534>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df.iloc[144]["Instruction"]=df.iloc[144]["Instruction"][8:]

# %%
df.iloc[144]['Instruction']="श्रुतीनां मूर्धानो दधति तव यौ शेखरतयाममाप्येतौ मातः शिरसि दयया धेहि चरणौ।ययोः पाद्यं पाथः पशुपतिजटाजूटतटिनी ययोर्लाक्षालक्ष्मीररुणहरिचूडामणिरुचिः॥"
# Out:
# <ipython-input-159-29d04aeda009>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
k=df.iloc[144]['Output'].index('|')
df.iloc[144]['Output']=df.iloc[144]['Output'][k+2:]
# Out:
# <ipython-input-174-aa327853e65c>:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df.iloc[144]['Output']=df.iloc[144]['Output'][k+2:]

# %%
df.iloc[145]['Output']=df.iloc[144]['Output']
# Out:
# <ipython-input-176-e64be3e1bd00>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df.iloc[145]['Output']=df.iloc[144]['Output']

# %%
df.iloc[145]['Instruction']="dśrutīnāṁ mūrdhāno dadhati tava yau śekharatayā mamāpyetau mātaḥ śirasi dayayā dhehi caraṇau | yayoḥ pādyaṁ pāthaḥ paśupatijaṭājūṭataṭinī yayorlākṣālakṣmīraruṇaharicūḍāmaṇiruciḥ ||"
# Out:
# <ipython-input-168-4f4b7c2a4929>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
df.iloc[145]['Instruction']
# Out:
# 'dśrutīnāṁ mūrdhāno dadhati tava yau śekharatayā mamāpyetau mātaḥ śirasi dayayā dhehi caraṇau | yayoḥ pādyaṁ pāthaḥ paśupatijaṭājūṭataṭinī yayorlākṣālakṣmīraruṇaharicūḍāmaṇiruciḥ ||'

# %%
df[140:]
# Out:
#     Verse                                        Instruction  \
# 140    71   नखानामुद्योतैर्ननवनलिनरागं विहसतांकराणां ते क...
# 141    71  nakhānāmudyotairnanavanalinarāgaṁ vihasatāṁkar...
# 142    72                  Twelve verses from verse 72 to 83
# 143    72                  Twelve verses from verse 72 to 83
# 144    84  श्रुतीनां मूर्धानो दधति तव यौ शेखरतयाममाप्येतौ...
# 145    84  dśrutīnāṁ mūrdhāno dadhati tava yau śekharatay...
# 146    85   नमोवाकं ब्रूमो नयनरमणीयाय पदयोःतवास्मै द्वन्द...
# 147    85  namovākaṁ brūmo nayanaramaṇīyāya padayoḥtavāsm...
# 148    86   मृषा कृत्वा गोत्रस्खलनमथ वैलक्ष्यनिमितंललाटे ...
# 149    86  mṛṣā kṛtvā gotraskhalanamatha vailakṣyanimitaṁ...
# 150    87   हिमानीहन्तव्यं हिमगिरिनिवासैकचतुरौनिशायां निद...
# 151    87  himānīhantavyaṁ himagirinivāsaikacaturauniśāyā...
# 152    88   पदं ते कीर्तीनां प्रपदमपदं देवि विपदांकथं नीत...
# 153    88  padaṁ te kīrtīnāṁ prapadamapadaṁ devi vipadāṁk...
# ...

# %%
df.to_csv('output.csv', index=False)
